# %% [markdown]
# ## Data

# %%
import pandas as pd

account = ['9040608', '9040608', '1235508', '6464408']
voucher = ['V1234', 'V1235','V1236', 'V1237']
posted = ['Y', 'Y', 'Y', 'N']
total = [631.2, 601.3, 721.3, 722.4]

data = {'Account': account,
       'Voucher':voucher,
       'Posted':posted,
       'Total':total}

data = pd.DataFrame(data)
data.head()
# Out:
#    Account Voucher Posted  Total
# 0  9040608   V1234      Y  631.2
# 1  9040608   V1235      Y  601.3
# 2  1235508   V1236      Y  721.3
# 3  6464408   V1237      N  722.4

# %%
Aaccount = ['9040608','9040608', '9040608', '1235508', '6464408']
Avoucher = ['V1233','V1234', 'V1235','V1236', 'V1237']
Aposted = ['Y','Y', 'Y', 'Y', 'N']
Atotal = [3031.67,631.2, 601.3, 731.3, 722.4]

access = {'Account': Aaccount,
       'Voucher':Avoucher,
       'Posted':Aposted,
       'Total': Atotal}

access = pd.DataFrame(access)
access
# Out:
#    Account Voucher Posted    Total
# 0  9040608   V1233      Y  3031.67
# 1  9040608   V1234      Y   631.20
# 2  9040608   V1235      Y   601.30
# 3  1235508   V1236      Y   731.30
# 4  6464408   V1237      N   722.40

# %%
df=data[['Account','Total', 'Posted']]
df.head()
# Out:
#    Account  Total Posted
# 0  9040608  631.2      Y
# 1  9040608  601.3      Y
# 2  1235508  721.3      Y
# 3  6464408  722.4      N

# %%
df=df.loc[df['Posted'] == 'Y']

# %%
df=df.groupby(['Account'])['Total'].sum().reset_index()
df.head()
# Out:
#    Account   Total
# 0  1235508   721.3
# 1  9040608  1232.5

# %%
accessDF=access.groupby(['Account'])['Total'].sum().reset_index()

accessDF.head()
# Out:
#    Account    Total
# 0  1235508   731.30
# 1  6464408   722.40
# 2  9040608  4264.17
